# %% [markdown]
# ## Writeup for Mr. Rooney

# %% [markdown]
# I looked at the stats for a lot of the players in the NBA, paying close attention to the ones that really make a difference like points per game, their shooting accuracy, and blocks per game. I looked specifically at 2025 for the NBA season, and extracted some data from there, making it easier to work with as I went along. I wanted to make sure you were able to pick the players who provide you and your team the most value for your money, so I used some more data-driven stuff to help out.
#
# The basic idea of what I did to the data/spreadsheet was I used some code to read in a couple data sheets, merge them together, and clean them up for use. I made sure to keep the key variables or components in there to help pick out the best players for your team. Just to keep everything transparent, I'll go through all the variables I decided to keep and why.
#
# First off, we obviously care about points, so I of course kept the amount of points each player scored, as well as assists. I also wanted to make sure to keep some defensive stats on there to keep it well-balanced and not skew it too much towards the offensive end of things, so I kept things like steals, blocks, and rebounds. I then proceeded to make these standard so I could compare them between players since some players obviously play more games than others. And of course, the main variable we care about, salary, was obviously kept so we could use this as a sort of output to look at.
#
# From here, we have a nice clean dataset to use, after some more cleaning and standardizing, but that's not something you need to worry too much about since I already handled that for you. We can then use this dataset to group up all the players into clusters of sorts, making categorizing them by the variables I mentioned previously. Using some algorithms and calculations to group these players into clusters will help us look at what we really care about: the best players to take. If you look at this graph below, you can see how the relationship between points per game and salary already start to group up these players since PPG will obviously have a pretty big impact on that player's salary.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# As you can see, my findings were that grouping these players into 3 clusters/groups is what was best for finding these players to take. I did experiment with some other values and did some calculations to make sure this is the best amount, so do not worry about that.
#
# Getting into these groups is where we can start to find some cutoffs for the stuff we care about, which is stats and how much their salary is. I started with the players we definitely don't want, which will be the players who don't score very often, but still have very high salaries. You don't want to buy them because why would you want to overpay for a player who barely scores anyway when you could get a player who scores more for less than half that salary? Below is a graph pointing to some of the players I'm talking about. The cutoffs I used were players who score less than 5 points per game, and have salaries of at least $10 million. These players would have minimal impact on your team's performance while making you pay a ton, so we don't want them. The main players I've selected to highlight this category are Lonzo Ball, Gabe Vincent, and Dorian Finney-Smith.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# As you can see, they really just aren't scoring very high, but they're still getting paid pretty well, and we don't want players that aren't going to perform, especially if we're paying them top dollar. So now we get into the category of players we actually do want, which is players who score a lot per game (15+), but don't have incredibly high salaries (cutoff of less than $5 million), making them easy pickings for obtaining them for the team. You can see a few of those players below such as Russell Westbrook, Ryan Rollins, and Keyonte George.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And the last category we have is the players who are decent, and if we can't get some of the players from the cluster of players I just mentioned before, these picks are fine too. They have pretty good points per game, but still have low salaries, so we can absolutely get them on the team if we want. The cutoffs I set for these players are players with points per game between 10 and 15, and salary under $7.5 million. They're still affordable, and even though they may not be the best pick, they're still quite good compared to other players. Here's the graph of those players, specifically pointing out Cam Spencer, Jaylon Tyson, and Walker Kessler.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Overall, we can easily see from these data points and graphs that there are some pretty clear winners here to choose from in terms of the stats I've curated for you. If I had to prioritize only a few players, I would definitely make sure my list includes Russell Westbrook, Keyonte George, and Walker Kessler. I hope you can use these suggestions to make the best team you can. Good luck!
